# %% [markdown]
# ## 12.1 Introduction to the Vision Transformer

# %%
from transformers import ViTModel

# %%
# vit_model = ViTModel.from_pretrained('google/vit-base-patch16-224-in21k')

# vit_model

# %% [markdown]
# ## 12.2 Combining ViT and GPT to caption images

# %%
from transformers import VisionEncoderDecoderModel, GPT2Tokenizer, Seq2SeqTrainer, Seq2SeqTrainingArguments
from PIL import Image
from torchvision import transforms
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
# Many weights are innitialized randomly, namely the cross attention weights
model = VisionEncoderDecoderModel.from_encoder_decoder_pretrained('google/vit-base-patch16-224-in21k', 'distilgpt2')
# Out:
# Some weights of GPT2LMHeadModel were not initialized from the model checkpoint at distilgpt2 and are newly initialized: ['transformer.h.5.crossattention.c_attn.weight', 'transformer.h.4.crossattention.masked_bias', 'transformer.h.3.crossattention.c_attn.weight', 'transformer.h.3.crossattention.c_proj.weight', 'transformer.h.4.crossattention.bias', 'transformer.h.4.ln_cross_attn.weight', 'transformer.h.1.crossattention.c_proj.weight', 'transformer.h.2.crossattention.c_attn.weight', 'transformer.h.1.crossattention.c_proj.bias', 'transformer.h.2.ln_cross_attn.weight', 'transformer.h.0.crossattention.c_attn.weight', 'transformer.h.4.crossattention.c_proj.bias', 'transformer.h.0.crossattention.c_proj.bias', 'transformer.h.3.crossattention.bias', 'transformer.h.5.crossattention.q_attn.weight', 'transformer.h.4.crossattention.c_proj.weight', 'transformer.h.4.crossattention.c_attn.weight', 'transformer.h.5.crossattention.bias', 'transformer.h.0.crossattention.q_attn.weight', 'transformer.h.0
# ...

# %%
image = Image.open('../data/flicker_images/3148647065_2d6cd88cf6.jpg')

image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x334 at 0x16616FC40>

# %%
image_matrix = np.asarray(image)
image_matrix.shape
# Out:
# (334, 500, 3)

# %% [markdown]
# ## 12.3 Fine-tuning an image captioning system

# %%
from transformers import VisionEncoderDecoderModel, GPT2Tokenizer, Seq2SeqTrainer, Seq2SeqTrainingArguments
from PIL import Image
from torchvision import transforms
import os
import matplotlib.pyplot as plt
import numpy as np
from datasets import Dataset
import torch
import numpy as np

# %%
MIN_SEQ_LENGTH, MAX_SEQ_LENGTH = 4, 7

gpt2_tokenizer = GPT2Tokenizer.from_pretrained(
    'distilgpt2', max_length=MAX_SEQ_LENGTH + 5, truncation=True
)

# %%
# Many weights are innitialized randomly, namely the cross attention weights
model = VisionEncoderDecoderModel.from_encoder_decoder_pretrained('google/vit-base-patch16-224-in21k', 'distilgpt2')
# Out:
# Some weights of GPT2LMHeadModel were not initialized from the model checkpoint at distilgpt2 and are newly initialized: ['transformer.h.3.crossattention.c_proj.bias', 'transformer.h.3.crossattention.bias', 'transformer.h.3.crossattention.q_attn.weight', 'transformer.h.2.crossattention.c_proj.bias', 'transformer.h.0.crossattention.masked_bias', 'transformer.h.2.crossattention.q_attn.weight', 'transformer.h.5.crossattention.c_proj.weight', 'transformer.h.3.crossattention.c_attn.weight', 'transformer.h.5.crossattention.c_attn.weight', 'transformer.h.0.crossattention.c_attn.weight', 'transformer.h.4.crossattention.c_proj.bias', 'transformer.h.4.crossattention.c_attn.weight', 'transformer.h.3.ln_cross_attn.weight', 'transformer.h.3.crossattention.masked_bias', 'transformer.h.5.crossattention.bias', 'transformer.h.4.crossattention.bias', 'transformer.h.2.crossattention.c_proj.weight', 'transformer.h.0.ln_cross_attn.weight', 'transformer.h.4.ln_cross_attn.weight', 'transformer.h.3.crossatte
# ...

# %%
model.config.decoder_start_token = gpt2_tokenizer.bos_token
model.config.decoder_start_token_id = gpt2_tokenizer.bos_token_id

# %%
IMAGES_PATH = '../data/flicker_images'

def load_captions_data(filename):
    with open(filename) as caption_file:
        caption_data = caption_file.readlines()
        caption_mapping = {}
        text_data = []

        for line in caption_data:
            line = line.rstrip("\n")
            # Image name and captions are separated using a tab
            img_name, caption = line.split("\t")

            # Each image is repeated five times for the five different captions.
            # Each image name has a suffix `#(caption_number)`
            img_name = img_name.split("#")[0]
            img_name = os.path.join(IMAGES_PATH, img_name.strip())

            if img_name.endswith("jpg"):
                # We will add a start and an end token to each caption
                caption = caption.replace(' .', '').strip()
                tokens = caption.strip().split()
                
                caption = f"{model.config.decoder_start_token} {caption} {gpt2_tokenizer.eos_token}"

                if len(tokens) < MIN_SEQ_LENGTH or len(tokens) > MAX_SEQ_LENGTH:
                    continue
                text_data.append(caption)

                if img_name in caption_mapping:
                    caption_mapping[img_name].append(caption)
                else:
                    caption_mapping[img_name] = [caption]

        return caption_mapping, text_data

# Load the dataset
captions_mapping, text_data = load_captions_data("/Users/sinanozdemir/Downloads/Flickr8k.token.txt")

# %%
list(captions_mapping.items())[:5]
# Out:
# [('../data/flicker_images/1000268201_693b08cb0e.jpg',
#   ['<|endoftext|> A girl going into a wooden building <|endoftext|>']),
#  ('../data/flicker_images/1007320043_627395c3d8.jpg',
#   ['<|endoftext|> A child playing on a rope net <|endoftext|>',
#    '<|endoftext|> A little girl climbing on red roping <|endoftext|>']),
#  ('../data/flicker_images/1015118661_980735411b.jpg',
#   ['<|endoftext|> A young boy runs aross the street <|endoftext|>']),
#  ('../data/flicker_images/1015584366_dfcec3c85a.jpg',
#   ['<|endoftext|> A black dog leaps over a log <|endoftext|>',
#    '<|endoftext|> The black dog jumped the tree stump <|endoftext|>']),
#  ('../data/flicker_images/101654506_8eb26cfb60.jpg',
#   ['<|endoftext|> A dog is running in the snow <|endoftext|>',
#    '<|endoftext|> A dog running through snow <|endoftext|>'])]

# %%
import pandas as pd

# %%
pd.DataFrame(captions_mapping)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [34], in <cell line: 1>()
# ----> 1 pd.DataFrame(captions_mapping)
#
# NameError: name 'pd' is not defined

# %%
class FlickerCaptionDataset(Dataset):
    """Flicker Caption Dataset"""

    def __init__(self, captions_mapping, transform, tokenizer):
        
        self.saved_images = {}

        self.captions_mapping = captions_mapping
        self.tokenizer = tokenizer
        self.tokenizer.pad_token = self.tokenizer.eos_token 
        
        self.paths, self.captions = [], []
#         i = 0
        for path, captions in self.captions_mapping.items():
            # pre-load image matrices
            im = Image.open(path)
            self.saved_images[path] = transform(im)
            im.close()
#             i += 1
            self.paths.append(path)
            self.captions.append(captions[0])  # only use the first caption
                
        self.tokenized_captions = self.tokenizer(self.captions, padding=True, truncation=True, return_tensors="pt")
             
        self.transform = transform

    def __len__(self):
        return len(self.paths)

    def __getitem__(self, idx):
        path = self.paths[idx]

        image, caption = self.saved_images[path], self.captions[idx]
        
        input_ids = self.tokenizer(self.captions[idx])['input_ids']
        
        sample = {'pixel_values': image, 
                  'caption': caption, 
                  'labels': self.tokenized_captions['input_ids'][idx],
                 }
        sample["labels"] = torch.tensor([-100 if x == self.tokenizer.pad_token_id else x for x in sample["labels"]])

        return sample

# %%
compose = transforms.Compose([
        transforms.Resize((224,224)),
        transforms.ToTensor(),
        transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5])
    ])

# %%
# Our model isn't so great.. YET
generated_captions = model.generate(
    sample_batch['pixel_values'], use_cache=True, max_length=MAX_SEQ_LENGTH + 2
)
generated_captions = [gpt2_tokenizer.decode(g, skip_special_tokens=True) for g in generated_captions]

f, axarr = plt.subplots(2,2, figsize=(10, 10))
axarr[0,0].imshow(sample_batch['pixel_values'][0].numpy().transpose(1, 2, 0))
axarr[0,0].set_title(generated_captions[0])
axarr[0,1].imshow(sample_batch['pixel_values'][1].numpy().transpose(1, 2, 0))
axarr[0,1].set_title(generated_captions[1])
axarr[1,0].imshow(sample_batch['pixel_values'][2].numpy().transpose(1, 2, 0))
axarr[1,0].set_title(generated_captions[2])
axarr[1,1].imshow(sample_batch['pixel_values'][3].numpy().transpose(1, 2, 0))
axarr[1,1].set_title(generated_captions[3])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [28], in <cell line: 2>()
#       1 # Our model isn't so great.. YET
#       2 generated_captions = model.generate(
# ----> 3     sample_batch['pixel_values'], use_cache=True, max_length=MAX_SEQ_LENGTH + 2
#       4 )
#       5 generated_captions = [gpt2_tokenizer.decode(g, skip_special_tokens=True) for g in generated_captions]
#       7 f, axarr = plt.subplots(2,2, figsize=(10, 10))
#
# NameError: name 'sample_batch' is not defined

# %%
gpt2_tokenizer.pad_token_id

# %%
# We set a pad token to supress a huggingface error
model.config.pad_token_id = gpt2_tokenizer.pad_token_id
model.config.decoder_start_token = gpt2_tokenizer.bos_token
model.config.decoder_start_token_id = gpt2_tokenizer.bos_token_id

# %%
sampled_captions_mapping = {k: v for k, v in list(captions_mapping.items())[:1000]}
sampled_captions_mapping = captions_mapping

print(len(sampled_captions_mapping))

flicker_dataset = FlickerCaptionDataset(sampled_captions_mapping, compose, gpt2_tokenizer)
# Out:
# 4841

# %%
flicker_dataset
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniforge/base/envs/pytorch_env/lib/python3.9/site-packages/IPython/core/formatters.py:707, in PlainTextFormatter.__call__(self, obj)
#     700 stream = StringIO()
#     701 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     702     self.max_width, self.newline,
#     703     max_seq_length=self.max_seq_length,
#     704     singleton_pprinters=self.singleton_printers,
#     705     type_pprinters=self.type_printers,
#     706     deferred_pprinters=self.deferred_printers)
# --> 707 printer.pretty(obj)
#     708 printer.flush()
#     709 return stream.getvalue()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/pytorch_env/lib/python3.9/site-packages/IPython/lib/pretty.py:410, in RepresentationPrinter.pretty(self, obj)
#     407                         return meth(obj, self, cycle)
# ...

# %%
flicker_dataset.train_test_split(test_size=0.2)

# %%
ninety = int(0.8 * len(flicker_dataset))

train_set, val_set = torch.utils.data.random_split(flicker_dataset, [ninety, len(flicker_dataset) - ninety])

# %%
# freeze all but the last three layers in the ViT
for name, param in model.encoder.named_parameters():
    if 'encoder.layer.9' in name:
        break
    param.requires_grad = False
    
# freeze all but the last three layers in the GPT model
for name, param in model.decoder.named_parameters():
    if 'transformer.h.3' in name:
        break
    param.requires_grad = False

# %%
MODEL_DIRECTORY = './image_captioning'


training_args = Seq2SeqTrainingArguments(
    output_dir=MODEL_DIRECTORY, #The output directory
    overwrite_output_dir=True, #overwrite the content of the output directory
    num_train_epochs=4, # number of training epochs
    per_device_train_batch_size=32, # batch size for training
    per_device_eval_batch_size=32,  # batch size for evaluation
    load_best_model_at_end=True,
    log_level='info',
    logging_steps=50,
    evaluation_strategy='epoch',
    save_strategy='epoch',
)

trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    train_dataset=train_set,
    eval_dataset=val_set,
)

# %%
trainer.evaluate()
# Out:
# ***** Running Evaluation *****
#   Num examples = 485
#   Batch size = 32
#     <div>
#
#       <progress value='32' max='16' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [16/16 31:08]
#     </div>
# {'eval_loss': 6.249879360198975,
#  'eval_runtime': 100.0309,
#  'eval_samples_per_second': 4.849,
#  'eval_steps_per_second': 0.16}

# %%
trainer.train()
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/pytorch_env/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use thePyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 4356
#   Num Epochs = 4
#   Instantaneous batch size per device = 32
#   Total train batch size (w. parallel, distributed & accumulation) = 32
#   Gradient Accumulation steps = 1
#   Total optimization steps = 548
#     <div>
#
#       <progress value='548' max='548' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [548/548 2:02:24, Epoch 4/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
# ...

# %%
trainer.save_model()
# Out:
# Saving model checkpoint to ./v2_image_captioning
# Configuration saved in ./v2_image_captioning/config.json
# Model weights saved in ./v2_image_captioning/pytorch_model.bin

# %%
# loading model and config from pretrained folder
finetuned_model = VisionEncoderDecoderModel.from_pretrained(MODEL_DIRECTORY)

# freeze model
finetuned_model.eval()
# Out:
# loading configuration file ./v2_image_captioning/config.json
# Model config VisionEncoderDecoderConfig {
#   "architectures": [
#     "VisionEncoderDecoderModel"
#   ],
#   "decoder": {
#     "_name_or_path": "distilgpt2",
#     "_num_labels": 1,
#     "activation_function": "gelu_new",
#     "add_cross_attention": true,
#     "architectures": [
#       "GPT2LMHeadModel"
#     ],
#     "attn_pdrop": 0.1,
#     "bad_words_ids": null,
#     "bos_token_id": 50256,
#     "chunk_size_feed_forward": 0,
#     "cross_attention_hidden_size": null,
#     "decoder_start_token_id": null,
#     "diversity_penalty": 0.0,
#     "do_sample": false,
#     "early_stopping": false,
#     "embd_pdrop": 0.1,
#     "encoder_no_repeat_ngram_size": 0,
#     "eos_token_id": 50256,
#     "finetuning_task": null,
#     "forced_bos_token_id": null,
#     "forced_eos_token_id": null,
#     "id2label": {
#       "0": "LABEL_0"
#     },
#     "initializer_range": 0.02,
#     "is_decoder": true,
# ...

# %%
finetuned_model(pixel_values=sample_batch['pixel_values'], labels=sample_batch['labels']).loss
# Out:
# tensor(2.9583, grad_fn=<NllLossBackward0>)

# %%
logits = finetuned_model(pixel_values=sample_batch['pixel_values'], labels=sample_batch['labels']).logits

# %%
generated_captions = finetuned_model.generate(
    sample_batch['pixel_values'], num_beams=4, top_k=16,
#     forced_bos_token_id=model.config.decoder_start_token_id,
    max_length=MAX_SEQ_LENGTH + 2
)
generated_captions = [gpt2_tokenizer.decode(g, skip_special_token=True) for g in generated_captions]

f, axarr = plt.subplots(2,2, figsize=(10, 10))
axarr[0,0].imshow(sample_batch['pixel_values'][0].numpy().transpose(1, 2, 0))
axarr[0,0].set_title(generated_captions[0])
axarr[0,1].imshow(sample_batch['pixel_values'][1].numpy().transpose(1, 2, 0))
axarr[0,1].set_title(generated_captions[1])
axarr[1,0].imshow(sample_batch['pixel_values'][2].numpy().transpose(1, 2, 0))
axarr[1,0].set_title(generated_captions[2])
axarr[1,1].imshow(sample_batch['pixel_values'][3].numpy().transpose(1, 2, 0))
axarr[1,1].set_title(generated_captions[3])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Text(0.5, 1.0, '<|endoftext|> A black dog jumps over a fence ')

# %%
import requests
from io import BytesIO

# a helper function to caption images from the web or a file path
def caption_image(m, path, n=4):
    if 'http' in path:
        response = requests.get(path)
        img = Image.open(BytesIO(response.content))
        image_matrix = np.asarray(np.expand_dims(compose(img), 0))
    else:
        img = Image.open(path)
        image_matrix = np.asarray(np.expand_dims(compose(img), 0))

    generated = m.generate(
        torch.tensor(image_matrix),
        num_beams=n,
        max_length=MAX_SEQ_LENGTH + 2,
        early_stopping=True,
        top_k=16,
        return_dict_in_generate=True,
        output_attentions=True,
        num_return_sequences=n,
)

    caption_options = [gpt2_tokenizer.decode(g, skip_special_tokens=True).strip() for g in generated.sequences]
    image_matrix  = image_matrix.squeeze(0).transpose(1, 2, 0)
    plt.imshow(image_matrix, interpolation='nearest')
    return caption_options, generated, image_matrix

# %%
captions, generated, image_matrix = caption_image(
    finetuned_model, 
    'https://cdn.pixabay.com/photo/2022/03/15/15/19/child-7070570_1280.jpg'
)
captions
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ['A child playing in a park',
#  'A young girl playing with a toy',
#  'A child playing in a playground',
#  'A boy playing in a park']

# %%
captions, generated, image_matrix = caption_image(
    finetuned_model, 
    '../data/flicker_images/1469000260_5d473c8283.jpg'
)
captions
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ['A dog is running in the grass',
#  'A black dog running through a field',
#  'A black dog running through the woods',
#  'A dog is running through the woods']

# %%
generated.cross_attentions[4][-1].shape
# Out:
# torch.Size([4, 12, 1, 197])

# %%
tokens = gpt2_tokenizer.convert_ids_to_tokens(generated.sequences[0], skip_special_tokens=False)[1:]
len(tokens), tokens
# Out:
# (8, ['ĠA', 'Ġdog', 'Ġis', 'Ġrunning', 'Ġin', 'Ġthe', 'Ġgrass', 'Ġ'])

# %%
f, axarr = plt.subplots(12, len(tokens), figsize=(50, 25))

for idx, token in enumerate(tokens):
    print(token, idx,'\n=============')
    for head in range(12):
        attention_patch = generated.cross_attentions[idx][-1][0][head][0][1:].reshape(14, 14)
        # min-max
        attention_patch = (attention_patch - attention_patch.min()) / (attention_patch.max() -  attention_patch.min())
        # make differennces more stark
        attention_patch = np.where(attention_patch < 0.4, 0, attention_patch)
        attention_patch = np.where(attention_patch < 0.8, attention_patch / 3, attention_patch)
        attention_patch = np.where(attention_patch >= 0.8, 1, attention_patch)
        attn_image_matrix = np.copy(image_matrix)
        for x in range(14):
            for y in range(14):
                attn_image_matrix[x*16: (x*16) + 16, y*16: (y*16) + 16] *= float(attention_patch[x, y])
        axarr[head,idx].imshow(attn_image_matrix, interpolation='hamming')        
        axarr[head,idx].set_title(f'token:{token},head:{head},idx:{idx}')
        axarr[head,idx].axis('off')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...

# %%
captions, generated, image_matrix = caption_image(
    VisionEncoderDecoderModel.from_pretrained(MODEL), 
    'https://cdn.pixabay.com/photo/2022/03/15/15/19/child-7070570_1280.jpg'
)
captions
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [37], in <cell line: 1>()
#       1 captions, generated, image_matrix = caption_image(
# ----> 2     VisionEncoderDecoderModel.from_pretrained(MODEL),
#       3     'https://cdn.pixabay.com/photo/2022/03/15/15/19/child-7070570_1280.jpg'
#       4 )
#       5 captions
#
# NameError: name 'MODEL' is not defined

# %%
from transformers import VisionEncoderDecoderModel, ViTFeatureExtractor, AutoTokenizer

MODEL = "nlpconnect/vit-gpt2-image-captioning"

third_party_model = VisionEncoderDecoderModel.from_pretrained(MODEL)
third_party_feature_extractor = ViTFeatureExtractor.from_pretrained(MODEL)
third_party_tokenizer = AutoTokenizer.from_pretrained(MODEL)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
third_party_model.to(device)


max_length = 16
num_beams = 4
gen_kwargs = {"max_length": max_length, "num_beams": num_beams}

def predict_step(image_paths):
    images = []
    for image_path in image_paths:
        i_image = Image.open(image_path)
        if i_image.mode != "RGB":
            i_image = i_image.convert(mode="RGB")

    images.append(i_image)

    pixel_values = third_party_feature_extractor(images=images, return_tensors="pt").pixel_values
    pixel_values = pixel_values.to(device)

    output_ids = third_party_model.generate(pixel_values, **gen_kwargs)

    preds = third_party_tokenizer.batch_decode(output_ids, skip_special_tokens=True)
    preds = [pred.strip() for pred in preds]
    return preds


predict_step(['../data/flicker_images/1469000260_5d473c8283.jpg'])

# %%
third_party_model(pixel_values=sample_batch['pixel_values'], labels=sample_batch['labels']).loss
